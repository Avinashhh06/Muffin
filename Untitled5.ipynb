# %%
import os
os.listdir("")

# %%
from tensorflow.keras.preprocessing.image from ImageDataGenerator
train_dir=""
test_dir=""
train_datagen=ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2
)

test_datagen=ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2
)

train_generator=train_datagen.flow_from_directory(
    train_dir, target_size=(256,256),
    batch_Size=32, class_mode='binary',subset='training'
)

validation_generator=train_daatagen.flow_from_directory(
    train_dir, target_size=(256,256),
    batch_size=32, class_mode='binary',
    subset='validation'
)

test_generator=test_datagen.flow_from_directory(
    test_dir, target_Size=(256,256),
    batch_Size=32, class_mode='binary',
    shuffle=False'
    )

# %%
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten,Dense,Dropout
from tensorflow.keras.callbacks import EarlyStopping

base_model=MobileNetV2(weights='imagenet',include_top=False,input_shape=(256,256,3))
base_model.trainable=False

model.Sequential([
    base_model,
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
early_stop=EarlyStopping(monitor='val_accuracy',patience=3,restore_best_weights=True)
model.fit(train_dir, validation_data=validation_generator,epochs=10, callbacks=[early_stop])

# %%
loss, acc=model.evaluate(test_generator)
print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {acc:.4f}")

# %%
import pandas as pd
import numpy as np

pred=model.predict(test_generator)

labels=(pred>0.5).astype(int).flatten()

filenames=[f.split('/')[-1] for f in test_generator.filenames]

submission=pd.DataFrame({
    'id':filenames,
    'label':labels
})

submission.to_csv('submission.csv',index=False)
print("CSV file generated successfully")

# %%
label = "chihuahua" if pred > 0.5 else "muffin"
submission = pd.DataFrame({
    'id': filenames,
    'label': predictions   # now contains strings instead of 0/1
})

submission.to_csv('submission.csv', index=False)

print("CSV file created successfully!")
submission['label'] = submission['label'].map({
    1: 'chihuahua',
    0: 'muffin'
})
